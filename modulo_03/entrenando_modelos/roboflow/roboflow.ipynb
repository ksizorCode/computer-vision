# %% [markdown]
# # Roboflow

# %%
# %pip uninstall scikit-image -y
# %pip install scikit-image --no-cache-dir

# %pip install --upgrade numpy
# %pip install --upgrade scikit-image
# %pip install --upgrade inference supervision

# %pip install numpy==1.24.4
# Out:
#   Cell In[2], line 10
#     conda create -n webcam_inference python=3.11
#           ^
# SyntaxError: invalid syntax

# %%
from inference import get_model
import supervision as sv
import cv2

# Cargar modelo
model = get_model(model_id="ejemplo01/f1-qoza3-instant-3")

# Crear annotators
bounding_box_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator()

# Abrir webcam (0 = cámara por defecto)
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("No se pudo abrir la webcam")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        print("No se pudo leer frame de la webcam")
        break

    # Inferencia en tiempo real
    results = model.infer(frame)[0]
    detections = sv.Detections.from_inference(results)

    # Annotar frame
    annotated_frame = bounding_box_annotator.annotate(scene=frame, detections=detections)
    annotated_frame = label_annotator.annotate(scene=annotated_frame, detections=detections)

    # Mostrar resultado
    cv2.imshow("Webcam Inference", annotated_frame)

    # Salir con 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Liberar recursos
cap.release()
cv2.destroyAllWindows()
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\visionado\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\visionado\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\visionado\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
# ...
