# %% [markdown]
# # Captura de pantalla básica
# Mostrar en una ventana el contenido que captura en la pantalla principal.
# (Q para cerrar Quit)

# %%
import cv2
import numpy as np
from PIL import ImageGrab

def adaptive_threshold_screen():
    """
    Versión con threshold adaptativo
    """
    print("Presiona 'q' para salir")
    
    while True:
        screenshot = ImageGrab.grab()
        frame = np.array(screenshot)
        # frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
        
        cv2.imshow('Captura de Pantalla', frame)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    cv2.destroyAllWindows()

if __name__ == "__main__":
    adaptive_threshold_screen()
# Out:
# Presiona 'q' para salir

# %% [markdown]
# # Captura de pantalla con filtro
# hace lo mismo que lo anterior pero le mete un filtro Threshold (umbral)

# %%
import cv2
import numpy as np
from PIL import ImageGrab

def adaptive_threshold_screen():
    """
    Versión con threshold adaptativo
    """
    print("Presiona 'q' para salir")
    
    while True:
        screenshot = ImageGrab.grab()
        frame = np.array(screenshot)
        frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        
        # Threshold adaptativo
        thresh = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                       cv2.THRESH_BINARY, 11, 2)
        
        cv2.imshow('Adaptive Threshold', thresh)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    cv2.destroyAllWindows()

if __name__ == "__main__":
    adaptive_threshold_screen()
# Out:
# Presiona 'q' para salir

# %% [markdown]
# # Captura de pantalla con varios filtros
# Pulsando la tecla "T" alternas entre diferentes filtros

# %%
import cv2
import numpy as np
from PIL import ImageGrab

def apply_threshold_to_screen():
    """
    Captura la pantalla continuamente y aplica un filtro threshold
    """
    print("Presiona 'q' para salir")
    print("Presiona 't' para cambiar entre threshold normal e inverso")
    print("Usa las teclas '+' y '-' para ajustar el valor del threshold")
    
    threshold_value = 127  # Valor inicial del threshold
    inverse = False  # Tipo de threshold
    
    while True:
        # Capturar la pantalla
        screenshot = ImageGrab.grab()
        
        # Convertir a array de numpy
        frame = np.array(screenshot)
        
        # Convertir de RGB a BGR (formato de OpenCV)
        frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
        
        # Convertir a escala de grises
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        
        # Aplicar threshold
        if inverse:
            _, thresh = cv2.threshold(gray, threshold_value, 255, cv2.THRESH_BINARY_INV)
        else:
            _, thresh = cv2.threshold(gray, threshold_value, 255, cv2.THRESH_BINARY)
        
        # Mostrar información en la imagen
        text = f"Threshold: {threshold_value} | Tipo: {'Inverso' if inverse else 'Normal'}"
        cv2.putText(thresh, text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 
                    1, (255, 255, 255), 2)
        
        # Mostrar la imagen con threshold
        cv2.imshow('Screen Threshold Filter', thresh)
        
        # Controles de teclado
        key = cv2.waitKey(1) & 0xFF
        
        if key == ord('q'):
            break
        elif key == ord('t'):
            inverse = not inverse
        elif key == ord('+') or key == ord('='):
            threshold_value = min(255, threshold_value + 5)
        elif key == ord('-'):
            threshold_value = max(0, threshold_value - 5)
    
    cv2.destroyAllWindows()

if __name__ == "__main__":
    apply_threshold_to_screen()
# Out:
# Presiona 'q' para salir
# Presiona 't' para cambiar entre threshold normal e inverso
# Usa las teclas '+' y '-' para ajustar el valor del threshold
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 58
#      55     cv2.destroyAllWindows()
#      57 if __name__ == "__main__":
# ---> 58     apply_threshold_to_screen()
#
# Cell In[2], line 18, in apply_threshold_to_screen()
#      14 inverse = False  # Tipo de threshold
#      16 while True:
#      17     # Capturar la pantalla
# ---> 18     screenshot = ImageGrab.grab()
#      20     # Convertir a array de numpy
#      21     frame = np.array(screenshot)
#
# File c:\Users\visionado\anaconda3\Lib\site-packages\PIL\ImageGrab.py:57, in grab(bbox, include_layered_windows, all_screens, xdisplay)
#      53 elif sys.platform == "win32":
#      54     offset, size, data = Image.core.grabscreen_win32(
# ...
